# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mohshaikh23/Campus-X-DSMP-2.0/refs/heads/main/Datasets/dataset-session-19/imdb-top-1000.csv")
df
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 0                             The Shawshank Redemption          1994      142
# 1                                        The Godfather          1972      175
# 2                                      The Dark Knight          2008      152
# 3                               The Godfather: Part II          1974      202
# 4                                         12 Angry Men          1957       96
# 5        The Lord of the Rings: The Return of the King          2003      201
# 6                                         Pulp Fiction          1994      154
# 7                                     Schindler's List          1993      195
# 8                                            Inception          2010      148
# 9                                           Fight Club          1999      139
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# ...

# %%
df.shape
# Out:
# (1000, 10)

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Runtime        1000 non-null   int64
#  3   Genre          1000 non-null   object
#  4   IMDB_Rating    1000 non-null   float64
#  5   Director       1000 non-null   object
#  6   Star1          1000 non-null   object
#  7   No_of_Votes    1000 non-null   int64
#  8   Gross          1000 non-null   float64
#  9   Metascore      843 non-null    float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 78.2+ KB

# %%
genre = df.groupby('Genre')
genre

# %%
genre.sum().head()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
#
#                                                Released_Year  Runtime  \
# Genre
# Action     2008200320102001200219991980197719621954200019...    22196
# Adventure  2014198520091981196819621959201319751963194819...     9656
# Animation  2001199419882016201820172008199719952019200920...     8166
# Biography  1993199020202011200220171995198420182013201320...    11970
# Comedy     2019199719361931200919641940200120001973196019...    17380
#
#            IMDB_Rating                                           Director  \
# Genre
# Action          1367.3  Christopher NolanPeter JacksonChristopher Nola...
# ...

# %%
genre.count()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172            172      172          172       172    172
# Adventure            72             72       72           72        72     72
# Animation            82             82       82           82        82     82
# Biography            88             88       88           88        88     88
# Comedy              155            155      155          155       155    155
# Crime               107            107      107          107       107    107
# Drama               289            289      289          289       289    289
# Family                2              2        2            2         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       11           11        11     11
# ...

# %%
df.groupby('Genre').sum()['Gross'].sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
df.groupby('Genre')['Gross'].sum().sort_values(ascending=False).head(3)
# Out:
# Genre
# Drama     3.540997e+10
# Action    3.263226e+10
# Comedy    1.566387e+10
# Name: Gross, dtype: float64

# %%
df.groupby('Genre')["IMDB_Rating"].mean().sort_values(ascending=False).head(1)
# Out:
# Genre
# Western    8.35
# Name: IMDB_Rating, dtype: float64

# %%
df.groupby('Director')["No_of_Votes"].sum().sort_values(ascending=False).head(1)
# Out:
# Director
# Christopher Nolan    11578345
# Name: No_of_Votes, dtype: int64

# %%
df.groupby(['Genre','Series_Title'])["IMDB_Rating"].sum()
# Out:
# Genre      Series_Title
# Action     300                                                                      7.6
#            3:10 to Yuma                                                             7.7
#            A Wednesday                                                              8.1
#            Aguirre, der Zorn Gottes                                                 7.9
#            Ajeossi                                                                  7.8
#            Aliens                                                                   8.3
#            Andaz Apna Apna                                                          8.2
#            Ang-ma-reul bo-at-da                                                     7.8
#            Apocalypto                                                               7.8
#            Avatar                                                                   7.8
# ...

# %%
df.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
df.groupby('Star1')['Series_Title'].count().sort_values(ascending=False)
# Out:
# Star1
# Tom Hanks                    12
# Robert De Niro               11
# Clint Eastwood               10
# Al Pacino                    10
# Leonardo DiCaprio             9
# Humphrey Bogart               9
# Johnny Depp                   8
# James Stewart                 8
# Christian Bale                8
# Toshirô Mifune                7
# Denzel Washington             7
# Aamir Khan                    7
# Charles Chaplin               6
# Cary Grant                    6
# Daniel Radcliffe              6
# Jake Gyllenhaal               6
# Tom Cruise                    6
# Ethan Coen                    6
# Paul Newman                   5
# Harrison Ford                 5
# Shah Rukh Khan                5
# Bruce Willis                  5
# Russell Crowe                 5
# Ethan Hawke                   5
# Dustin Hoffman                5
# William Holden                4
# Gene Hackman                  4
# Charlton Heston               4
# Akshay Kumar                  4
# ...

# %%
len(df.groupby('Genre'))
# Out:
# 14

# %%
df.groupby('Genre').size()
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
genres = df.groupby('Genre')
genres

# %%
genres.first()
# Out:
#                               Series_Title Released_Year  Runtime  \
# Genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
genres.last()
# Out:
#                                   Series_Title Released_Year  Runtime  \
# Genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
genres.nth(4)
# Out:
#                               Series_Title Released_Year  Runtime      Genre  \
# 13   The Lord of the Rings: The Two Towers          2002      179     Action
# 20                         Soorarai Pottru          2020      153      Drama
# 22                          Cidade de Deus          2002      130      Crime
# 38                             The Pianist          2002      150  Biography
# 58       Spider-Man: Into the Spider-Verse          2018      117  Animation
# 64                                3 Idiots          2009      170     Comedy
# 114                  2001: A Space Odyssey          1968      149  Adventure
# 220                                Kahaani          2012      122    Mystery
# 544               Night of the Living Dead          1968       96     Horror
#
#      IMDB_Rating            Director         Star1  No_of_Votes        Gross  \
# 13           8.7       Peter Jackson   Elijah Wood      1485555  342551365.0
# ...

# %%
genres.get_group('Action')
# Out:
#                                           Series_Title Released_Year  Runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# 14                                          The Matrix          1999      136
# 16      Star Wars: Episode V - The Empire Strikes Back          1980      124
# 29                                           Star Wars          1977      121
# 30                                             Seppuku          1962      133
# 31                                Shichinin no samurai          1954      207
# 39                                           Gladiator          2000      155
# ...

# %%
genres.groups
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
genres.describe()
# Out:
#           Runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# Genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
genres.sample(2,replace=True)
# Out:
#                             Series_Title Released_Year  Runtime      Genre  \
# 31                  Shichinin no samurai          1954      207     Action
# 702                     Bonnie and Clyde          1967      111     Action
# 884             The Peanut Butter Falcon          2019       97  Adventure
# 247    Lagaan: Once Upon a Time in India          2001      224  Adventure
# 522                        Jûbê ninpûchô          1993       94  Animation
# 219                      Song of the Sea          2014       93  Animation
# 157                        Der Untergang          2004      156  Biography
# 766            The Last King of Scotland          2006      123  Biography
# 726                 En man som heter Ove          2015      116     Comedy
# 435                        La dolce vita          1960      174     Comedy
# 6                           Pulp Fiction          1994      154      Crime
# ...

# %%
genres.nunique()
# Out:
#            Series_Title  Released_Year  Runtime  IMDB_Rating  Director  Star1  \
# Genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
genres.sum()
# Out:
#                                                 Series_Title  \
# Genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
genres.agg(
    {
        'Runtime':['min','max'],
        'IMDB_Rating':['sum'],
        'No_of_Votes':['mean'],
        'Gross':['min','mean','max'],
        'Metascore':['std']
    }
)
# Out:
#           Runtime      IMDB_Rating    No_of_Votes        Gross                \
#               min  max         sum           mean          min          mean
# Genre
# Action         45  321      1367.3  420246.581395       3296.0  1.897224e+08
# Adventure      88  228       571.5  313557.819444      61001.0  1.319017e+08
# Animation      71  137       650.3  268032.073171     128985.0  1.784326e+08
# Biography      93  209       698.6  272805.045455      21877.0  9.404952e+07
# Comedy         68  188      1224.7  178195.658065       1305.0  1.010572e+08
# Crime          80  229       857.8  313398.271028       6013.0  7.899656e+07
# Drama          64  242      2299.7  212343.612457       3600.0  1.225259e+08
# Family        100  115        15.6  275610.500000    4000000.0  2.195553e+08
# Fantasy        76   94        16.0   73111.000000  337574718.0  3.913633e+08
# Film-Noir     100  108        23.9  122405.000000     449191.0  4.197018e+07
# ...

# %%
for group,data in genres:
    print(type(group),type(data))
# Out:
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>
# <class 'str'> <class 'pandas.core.frame.DataFrame'>

# %%
genres['Runtime'].apply(lambda x: x**2)
# Out:
# Genre
# Action     2       23104
#            5       40401
#            8       21904
#            10      31684
#            13      32041
#            14      18496
#            16      15376
#            29      14641
#            30      17689
#            31      42849
#            39      24025
#            42      12100
#            44      18769
#            55      21609
#            57      25921
#            59      32761
#            60      22201
#            63      26896
#            68      10201
#            72      13225
#            106     18769
#            109     17161
#            129     19044
#            130     24336
#            134     27889
#            140    103041
#            142     18225
#            144     19600
#            152     17424
#            155     19600
#            160     24336
#            161     11449
#            166     25600
#            168     16129
#            171     17424
#            172     26244
# ...

# %%
def ranking(group):
    group['rank'] = group['IMDB_Rating'].rank(ascending=False)
    return group

# %%
genres.apply(ranking)
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_18360\1444372559.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(ranking)
#                                                     Series_Title  \
# Genre
# Action    2                                      The Dark Knight
#           5        The Lord of the Rings: The Return of the King
#           8                                            Inception
#           10   The Lord of the Rings: The Fellowship of the Ring
#           13               The Lord of the Rings: The Two Towers
#           14                                          The Matrix
#           16      Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
def normal(group):
    group['norm_rating'] = (group['IMDB_Rating']-group['IMDB_Rating'].min())/(group['IMDB_Rating'].max()- group['IMDB_Rating'].min())
    return group

# %%
genres.apply(normal)
# Out:
# C:\Users\mohsi\AppData\Local\Temp\ipykernel_18360\1987004062.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   genres.apply(normal)
#                                                     Series_Title  \
# Genre
# Action    2                                      The Dark Knight
#           5        The Lord of the Rings: The Return of the King
#           8                                            Inception
#           10   The Lord of the Rings: The Fellowship of the Ring
#           13               The Lord of the Rings: The Two Towers
#           14                                          The Matrix
#           16      Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
duo= df.groupby(["Director",'Star1'])

# %%
duo['Gross'].sum().sort_values(ascending=False).head(1)
# Out:
# Director        Star1
# Akira Kurosawa  Toshirô Mifune    2.999877e+09
# Name: Gross, dtype: float64

# %%
df.groupby(['Star1','Genre'])['Metascore'].mean().reset_index().sort_values('Metascore',ascending=False)
# Out:
#                          Star1      Genre   Metascore
# 230             Ellar Coltrane      Drama  100.000000
# 329            Humphrey Bogart      Drama  100.000000
# 360              James Stewart    Mystery  100.000000
# 77                 Bertil Guve      Drama  100.000000
# 590               Orson Welles      Drama  100.000000
# 127                 Cary Grant      Drama  100.000000
# 606              Peter O'Toole  Adventure  100.000000
# 140            Charlton Heston      Crime   99.000000
# 653             Robert Mitchum      Crime   99.000000
# 278                 Gene Kelly     Comedy   99.000000
# 515          Margaret Lockwood    Mystery   98.000000
# 340              Ivana Baquero      Drama   98.000000
# 773             Toshirô Mifune      Crime   98.000000
# 771             Toshirô Mifune     Action   98.000000
# 125                 Cary Grant  Adventure   98.000000
# 520             Marilyn Monroe     Comedy   98.000000
# ...

# %%
duo['IMDB_Rating'].agg(['min','max','mean'])
# Out:
#                                                             min  max      mean
# Director                         Star1
# Aamir Khan                       Amole Gupte                8.4  8.4  8.400000
# Aaron Sorkin                     Eddie Redmayne             7.8  7.8  7.800000
# Abdellatif Kechiche              Léa Seydoux                7.7  7.7  7.700000
# Abhishek Chaubey                 Shahid Kapoor              7.8  7.8  7.800000
# Abhishek Kapoor                  Amit Sadh                  7.7  7.7  7.700000
# Adam Elliot                      Toni Collette              8.1  8.1  8.100000
# Adam McKay                       Christian Bale             7.8  7.8  7.800000
# Aditya Chopra                    Shah Rukh Khan             8.1  8.1  8.100000
# Aditya Dhar                      Vicky Kaushal              8.2  8.2  8.200000
# Akira Kurosawa                   Takashi Shimura            8.3  8.3  8.300000
# ...

# %%
df= pd.read_csv('https://raw.githubusercontent.com/Mohshaikh23/Campus-X-DSMP-2.0/refs/heads/main/Datasets/dataset-session-19/deliveries.csv')
df.head(15)
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 0          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 5          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 6          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 7          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 8          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 9          1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# ...

# %%
df['match_id'].value_counts().sort_index()
# Out:
# match_id
# 1        248
# 2        247
# 3        218
# 4        247
# 5        248
# 6        216
# 7        254
# 8        212
# 9        226
# 10       239
# 11       234
# 12       243
# 13       236
# 14       250
# 15       248
# 16       251
# 17       250
# 18       245
# 19       249
# 20       249
# 21       245
# 22       225
# 23       232
# 24       252
# 25       245
# 26       245
# 27       183
# 28       245
# 29       239
# 30       212
# 31       221
# 32       243
# 33       245
# 34       263
# 35       157
# 36       247
# 37       245
# 38       244
# 39       240
# 40       238
# 41       234
# 42       240
# 43       246
# 44       211
# 45       216
# 46       244
# 47       238
# 48       248
# 49       243
# 50       255
# 51       249
# 52       228
# 53       250
# 54       171
# 55       249
# 56       252
# 57       157
# 58       207
# 59       248
# 60       225
# 61       248
# 62       219
# 63       246
# 64       240
# 65       241
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
df.shape
# Out:
# (179078, 21)

# %%
df.groupby('batsman')['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
df[df['batsman_runs']==6].groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(1)
# Out:
# batsman
# CH Gayle    327
# Name: batsman_runs, dtype: int64

# %%
ndf = df[(df['over'] > 15) & ((df['batsman_runs']==4) | (df['batsman_runs']==6))]
ndf.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False)
# Out:
# batsman
# MS Dhoni             340
# AB de Villiers       208
# RG Sharma            208
# KA Pollard           206
# V Kohli              160
# YK Pathan            149
# KD Karthik           145
# Yuvraj Singh         130
# AD Russell           129
# AT Rayudu            114
# SK Raina             106
# DJ Bravo             105
# JP Duminy            104
# HH Pandya            102
# RA Jadeja            102
# DA Miller             99
# Harbhajan Singh       92
# IK Pathan             86
# SPD Smith             78
# JA Morkel             77
# BJ Hodge              76
# CH Gayle              76
# RR Pant               76
# MK Tiwary             73
# DA Warner             70
# RV Uthappa            68
# KM Jadhav             65
# SR Watson             63
# WP Saha               60
# MK Pandey             59
# AM Rahane             58
# S Dhawan              58
# SV Samson             56
# JH Kallis             56
# PP Chawla             55
# KH Pandya             55
# ...

# %%
temp_df = pd.DataFrame()
temp_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
temp= df[df['batsman'] == 'V Kohli']
temp_df['total_runs'] = temp.groupby("bowling_team")['batsman_runs'].sum().sort_index(ascending=True)

# %%
temp_df['fours']= temp[temp["batsman_runs"] == 4].groupby('bowling_team')['batsman_runs'].count()

# %%
temp_df['Sixes'] = temp[temp["batsman_runs"] == 6].groupby('bowling_team')['batsman_runs'].count()

# %%
temp_df['Average_Runs'] = temp.groupby('bowling_team')['batsman_runs'].mean()

# %%
temp_df['Min_Runs'] = temp.groupby('bowling_team')['batsman_runs'].min()

# %%
temp_df['Max_Runs'] = temp.groupby('bowling_team')['batsman_runs'].max()

# %%
temp.groupby('bowling_team')[['match_id','batsman_runs']]
# Out:
#                          match_id  batsman_runs
# bowling_team
# Chennai Super Kings         11330             6
# Deccan Chargers               376             6
# Delhi Capitals              11337             6
# Delhi Daredevils             7938             6
# Gujarat Lions                 633             6
# Kings XI Punjab             11333             6
# Kochi Tuskers Kerala          283             4
# Kolkata Knight Riders       11326             6
# Mumbai Indians              11322             6
# Pune Warriors                 426             6
# Rajasthan Royals            11340             6
# Rising Pune Supergiant         33             6
# Rising Pune Supergiants       611             6
# Sunrisers Hyderabad         11345             6

# %%
temp_df
# Out:
#                          total_runs  fours  Sixes  Average_Runs  Min_Runs  \
# bowling_team
# Chennai Super Kings             749     57   30.0      1.215909         0
# Deccan Chargers                 306     23   14.0      1.330435         0
# Delhi Capitals                   66      3    3.0      1.320000         0
# Delhi Daredevils                763     74   22.0      1.379747         0
# Gujarat Lions                   283     24   11.0      1.521505         0
# Kings XI Punjab                 636     74   18.0      1.284848         0
# Kochi Tuskers Kerala             50      7    NaN      0.961538         0
# Kolkata Knight Riders           675     58   22.0      1.310680         0
# Mumbai Indians                  628     52   24.0      1.263581         0
# Pune Warriors                   128      9    5.0      1.267327         0
# Rajasthan Royals                370     29   10.0      1.054131         0
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
def max_scorer(batsman):
    return df[df['batsman']==batsman].groupby('match_id')['batsman_runs'].sum().sort_values(ascending=False).head(1).values[0]

# %%
max_scorer("V Kohli")
# Out:
# 113

# %%
max_scorer("DA Warner")
# Out:
# 126

# %%
courses = pd.read_csv('Session 20 - Merging/datasets-session-20/courses.csv')
students = pd.read_csv('Session 20 - Merging/datasets-session-20/students.csv')
nov = pd.read_csv('Session 20 - Merging/datasets-session-20/reg-month1.csv')
dec = pd.read_csv('Session 20 - Merging/datasets-session-20/reg-month2.csv')

matches = pd.read_csv('Session 20 - Merging/datasets-session-20/matches.csv')
delivery = pd.read_csv('Session 20 - Merging/datasets-session-20/deliveries.csv')

# %%
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students.head()
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
nov.head()
# Out:
#    student_id  course_id
# 0          23          1
# 1          15          5
# 2          18          6
# 3          23          4
# 4          16          9

# %%
dec.head()
# Out:
#    student_id  course_id
# 0           3          5
# 1          16          7
# 2          12         10
# 3          12          1
# 4          14          9

# %%
regs = pd.concat([nov,dec],axis=0,ignore_index=True)
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
multi = pd.concat([nov,dec],keys=['Nov','Dec'])
multi
# Out:
#         student_id  course_id
# Nov 0           23          1
#     1           15          5
#     2           18          6
#     3           23          4
#     4           16          9
#     5           18          1
#     6            1          1
#     7            7          8
#     8           22          3
#     9           15          1
#     10          19          4
#     11           1          6
#     12           7         10
#     13          11          7
#     14          13          3
#     15          24          4
#     16          21          1
#     17          16          5
#     18          23          3
#     19          17          7
#     20          23          6
#     21          25          1
#     22          19          2
#     23          25         10
#     24           3          3
# Dec 0            3          5
#     1           16          7
#     2           12         10
#     3           12          1
#     4           14          9
# ...

# %%
multi.loc[('Nov',6)]
# Out:
# student_id    1
# course_id     1
# Name: (Nov, 6), dtype: int64

# %%
pd.concat([nov,dec],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
regs
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
students.head()
# Out:
#    student_id            name  partner
# 0           1   Kailash Harjo       23
# 1           2     Esha Butala        1
# 2           3  Parveen Bhalla        3
# 3           4     Marlo Dugal       14
# 4           5     Kusum Bahri        6

# %%
data =pd.merge(left=students,right=regs,how='outer',left_on='student_id',right_on='student_id')
data
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo     23.0        1.0
# 1            1       Kailash Harjo     23.0        6.0
# 2            1       Kailash Harjo     23.0       10.0
# 3            1       Kailash Harjo     23.0        9.0
# 4            2         Esha Butala      1.0        5.0
# 5            3      Parveen Bhalla      3.0        3.0
# 6            3      Parveen Bhalla      3.0        5.0
# 7            4         Marlo Dugal     14.0        NaN
# 8            5         Kusum Bahri      6.0        NaN
# 9            6  Lakshmi Contractor     10.0        NaN
# 10           7        Tarun Thaker      9.0        8.0
# 11           7        Tarun Thaker      9.0       10.0
# 12           7        Tarun Thaker      9.0        7.0
# 13           7        Tarun Thaker      9.0        2.0
# 14           7        Tarun Thaker      9.0        6.0
# 15           8      Radheshyam Dey      5.0        NaN
# ...

# %%
print('Data shape -',data.shape)
print('courses shape -',courses.shape)

print("Left - ",data.merge(courses,how='left',on='course_id').shape)
print("Right - ",data.merge(courses,how='right',on='course_id').shape)
print('Outer - ',data.merge(courses,how='outer',on='course_id').shape)
print('Inner - ',data.merge(courses,how='inner',on='course_id').shape)
# Out:
# Data shape - (60, 4)
# courses shape - (12, 3)
# Left -  (60, 6)
# Right -  (55, 6)
# Outer -  (62, 6)
# Inner -  (53, 6)

# %%
data.merge(courses,how='inner',on='course_id')['price'].sum()
# Out:
# 154247

# %%
new_data =pd.concat([nov,dec],keys =['Nov','Dec']).reset_index()
new_data.merge(courses,on='course_id').groupby('level_0')['price'].sum()
# Out:
# level_0
# Dec    65072
# Nov    89175
# Name: price, dtype: int64

# %%
regs.merge(students,on='student_id').merge(courses,on='course_id')[['name','course_name','price']]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1            Preet Sha           tableau   2499
# 2      Fardeen Mahabir          power bi   1899
# 3       Chhavi Lachman  machine learning   9999
# 4         Elias Dodiya            plotly    699
# 5      Fardeen Mahabir            python   2499
# 6        Kailash Harjo            python   2499
# 7         Tarun Thaker            pandas   1099
# 8           Yash Sethi     data analysis   4999
# 9            Preet Sha            python   2499
# 10        Qabeel Raman  machine learning   9999
# 11       Kailash Harjo          power bi   1899
# 12        Tarun Thaker           pyspark   2499
# 13  David Mukhopadhyay          ms sxcel   1599
# 14      Munni Varghese     data analysis   4999
# 15        Radhika Suri  machine learning   9999
# 16          Seema Kota            python   2499
# 17        Elias Dodiya           tableau   2499
# 18      Chhavi Lachman     data analysis   4999
# ...

# %%
regs.merge(courses,on='course_id').groupby('course_name')['price'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='course_name'>

# %%
pd.concat([nov,dec],axis=1)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
common= np.intersect1d(nov['student_id'],dec['student_id'])
common
# Out:
# array([ 1,  3,  7, 11, 16, 17, 18, 22, 23], dtype=int64)

# %%
students[students['student_id'].isin(common)]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %%
students[students['student_id'].isin(np.setdiff1d(courses['course_id'],regs['course_id']))]
# Out:
#     student_id                name  partner
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19

# %%
a = courses.merge(regs,how='outer')
a[a['student_id'].isna()]
# Out:
#     course_id course_name  price  student_id
# 53         11       Numpy    699         NaN
# 54         12         C++   1299         NaN

# %%
print(students.columns)
print(regs.columns)
print(courses.columns)
# Out:
# Index(['student_id', 'name', 'partner'], dtype='object')
# Index(['student_id', 'course_id'], dtype='object')
# Index(['course_id', 'course_name', 'price'], dtype='object')

# %%
s = students.merge(regs,how='outer').merge(courses,how='outer')
s[s['course_name'].isna()]
# Out:
#     student_id                name  partner  course_id course_name  price
# 55         4.0         Marlo Dugal     14.0        NaN         NaN    NaN
# 56         5.0         Kusum Bahri      6.0        NaN         NaN    NaN
# 57         6.0  Lakshmi Contractor     10.0        NaN         NaN    NaN
# 58         8.0      Radheshyam Dey      5.0        NaN         NaN    NaN
# 59         9.0   Nitika Chatterjee      4.0        NaN         NaN    NaN
# 60        10.0      Aayushman Sant      8.0        NaN         NaN    NaN
# 61        20.0       Hanuman Hegde     11.0        NaN         NaN    NaN

# %%
students.merge(students,how='inner',left_on='student_id',right_on='partner')[['name_x','name_y']]
# Out:
#                 name_x              name_y
# 0        Kailash Harjo         Esha Butala
# 1          Esha Butala     Shashank D’Alia
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal   Nitika Chatterjee
# 4          Kusum Bahri      Radheshyam Dey
# 5   Lakshmi Contractor         Kusum Bahri
# 6         Tarun Thaker        Yasmin Palan
# 7       Radheshyam Dey      Aayushman Sant
# 8    Nitika Chatterjee        Tarun Thaker
# 9       Aayushman Sant  Lakshmi Contractor
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese     Fardeen Mahabir
# 13    Pranab Natarajan         Marlo Dugal
# 14           Preet Sha          Seema Kota
# 15        Elias Dodiya           Preet Sha
# 16        Yasmin Palan        Radhika Suri
# 17     Fardeen Mahabir      Chhavi Lachman
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota          Yash Sethi
# ...

# %%
regs.merge(students,on='student_id').groupby(['student_id','name'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23          Chhavi Lachman    6
# 7           Tarun Thaker      5
# 1           Kailash Harjo     4
# Name: name, dtype: int64

# %%
s.groupby(['student_id','name'])['name'].count().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23.0        Chhavi Lachman    6
# 7.0         Tarun Thaker      5
# 1.0         Kailash Harjo     4
# Name: name, dtype: int64

# %%
s.groupby(['student_id','name'])['price'].sum().sort_values(ascending=False).head(3)
# Out:
# student_id  name
# 23.0        Chhavi Lachman      22594.0
# 14.0        Pranab Natarajan    15096.0
# 19.0        Qabeel Raman        13498.0
# Name: price, dtype: float64

# %%
ipl= pd.read_csv('https://raw.githubusercontent.com/Mohshaikh23/Campus-X-DSMP-2.0/refs/heads/main/Datasets/datasets-session-20/deliveries.csv')
ipl.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0          0         0
# 1     2  DA Warner    S Dhawan  TS Mills              0          0         0
# 2     3  DA Warner    S Dhawan  TS Mills              0          0         0
# 3     4  DA Warner    S Dhawan  TS Mills              0          0         0
# 4     5  DA Warner    S Dhawan  TS Mills              0          2         0
#
# ...

# %%
ipl.shape
# Out:
# (150460, 21)

# %%
matches = pd.read_csv('https://raw.githubusercontent.com/Mohshaikh23/Campus-X-DSMP-2.0/refs/heads/main/Datasets/datasets-session-20/matches.csv')
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ipl.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder'],
#       dtype='object')

# %%
matches.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
df = ipl.merge(matches, how='inner',left_on='match_id',right_on='id')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  wide_runs  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0          0         0
# 1     2  DA Warner    S Dhawan  TS Mills              0          0         0
# 2     3  DA Warner    S Dhawan  TS Mills              0          0         0
# 3     4  DA Warner    S Dhawan  TS Mills              0          0         0
# 4     5  DA Warner    S Dhawan  TS Mills              0          2         0
#
# ...

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
sixes= df[df['batsman_runs']==6]
sixes.head()
# Out:
#     match_id  inning         batting_team                 bowling_team  over  \
# 10         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     2
# 47         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     8
# 75         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    13
# 89         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
# 91         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore    15
#
#     ball       batsman   non_striker       bowler  is_super_over  wide_runs  \
# 10     4     DA Warner      S Dhawan  A Choudhary              0          0
# 47     4  MC Henriques      S Dhawan      TM Head              0          0
# 75     2  Yuvraj Singh  MC Henriques  A Choudhary              0          0
# 89     3  Yuvraj Singh  MC Henriques    S Aravind              0          0
# 91     5  MC Henriques  Yuvraj Singh    S Aravind              0          0
#
# ...

# %%
num_sixes = sixes.groupby('venue')['venue'].count()

# %%
matches_count= matches.venue.value_counts()

# %%
new_df= num_sixes/matches_count

# %%
new_df.sort_values(ascending=False).head()
# Out:
# venue
# Holkar Cricket Stadium                                 17.600000
# M Chinnaswamy Stadium                                  13.227273
# Sharjah Cricket Stadium                                12.666667
# Himachal Pradesh Cricket Association Stadium           12.000000
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium    11.727273
# dtype: float64

# %%
df.columns
# Out:
# Index(['match_id', 'inning', 'batting_team', 'bowling_team', 'over', 'ball',
#        'batsman', 'non_striker', 'bowler', 'is_super_over', 'wide_runs',
#        'bye_runs', 'legbye_runs', 'noball_runs', 'penalty_runs',
#        'batsman_runs', 'extra_runs', 'total_runs', 'player_dismissed',
#        'dismissal_kind', 'fielder', 'id', 'season', 'city', 'date', 'team1',
#        'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied',
#        'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue',
#        'umpire1', 'umpire2', 'umpire3'],
#       dtype='object')

# %%
df.groupby(['season','batsman'])['batsman_runs'].sum().reset_index().sort_values('batsman_runs',ascending=False).drop_duplicates(subset='season',keep='first').sort_index()
# Out:
#       season       batsman  batsman_runs
# 115     2008      SE Marsh           616
# 229     2009     ML Hayden           572
# 446     2010  SR Tendulkar           618
# 502     2011      CH Gayle           608
# 684     2012      CH Gayle           733
# 910     2013    MEK Hussey           733
# 1088    2014    RV Uthappa           660
# 1148    2015     DA Warner           562
# 1383    2016       V Kohli           973
# 1422    2017     DA Warner           641
